# %% [markdown]
# <a href="https://colab.research.google.com/github/norah-csaki/BTE320-Repository/blob/main/bte320_inclassassignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In-Class Assignment 1
sales = float(input("Enter sales ($): "))
tax_rate = float(input("Enter tax rate (%): "))
cogs = 0.4 * sales
gross_profit = sales - cogs
tax = gross_profit * (tax_rate / 100)
net_income = gross_profit - tax
print(f"Sales: ${sales:,.1f}")
print(f"Cost of Goods Sold: ${cogs:,.2f}")
print(f"Gross Profit: ${gross_profit:,.2f}")
print(f"Taxes: ${tax:,.2f}")
print(f"Net Income: ${net_income:,.2f}")
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 30
# Sales: $12,000.0
# Cost of Goods Sold: $4,800.00
# Gross Profit: $7,200.00
# Taxes: $2,160.00
# Net Income: $5,040.00

# %%
# In-Class Assignment 2
import math

demand = float(input("Enter annual demand (units/year): "))
order_cost = float(input("Enter ordering cost ($/order): "))
holding_cost = float(input("Enter annual holding cost per unit ($/year/unit): "))


eoq = math.sqrt((2 * demand * order_cost) / holding_cost)

print(f"The Economic Order Quantity (EOQ) is: {eoq:.2f}")

# %%
# In-Class Assignment 3
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /, **, //, %): ")

if operator == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator == "-":
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator == "*":
    result = num1 * num2
    print(f"{num1} * {num2} = {result}")
elif operator == "/":
    result = num1 / num2
    print(f"{num1} / {num2} = {result}")
elif operator == "**":
    result = num1 ** num
    print(f"{num1} ** {num2} = {result}")
elif operator == "//":
    result = num1 // num2
    print(f"{num1} // {num2} = {result}")
elif operator == "%":
    result = num1 % num2
    print(f"{num1} % {num2} = {result}")
else:
    print("Invalid operator")
# Out:
# Enter first number: 1
# Enter second number: 2
# Enter operator (+, -, *, /, **, //, %): =
# Invalid operator

# %%
# In-Class Assignment 4
base_fee = 5.0
hourly_rate = 2.5

for i in range(1, 9):
  fee = base_fee + (i) * hourly_rate
  if fee < 10.0:
    fee = 10.0
  elif fee > 20.0:
    fee = 20.0
  print(f"{i} {fee}")
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
# In-Class Assignment 5
init_attendees = 20
fixed_cost = 200

print("Ad$ Profit")
for i in range(0, 201, 25):
  revenue = (init_attendees + 2 * round(i ** 0.5)) * 10
  costs = fixed_cost + i
  profit = revenue - costs
  print(float(i), float(profit))
# Out:
# Ad$ Profit
# 0.0 0.0
# 25.0 75.0
# 50.0 90.0
# 75.0 105.0
# 100.0 100.0
# 125.0 95.0
# 150.0 90.0
# 175.0 85.0
# 200.0 80.0

# %%
# In-Class Assignment 4 (while-loop edition)
base_fee = 5.0
hourly_rate = 2.5
i = 1

while i >= 1 and i <= 8:
  fee = base_fee + (i) * hourly_rate
  if fee < 10.0:
    fee = 10.0
  elif fee > 20.0:
    fee = 20.0
  print(f"{i} {fee}")
  i+=1
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
# In-Class Assignment 5 (while-loop edition)
init_attendees = 20
fixed_cost = 200
i = 0.0

print("Ad$ Profit")
while i >= 0 and i <= 200:
  revenue = (init_attendees + 2 * round(i ** 0.5)) * 10
  costs = fixed_cost + i
  profit = revenue - costs
  print(float(i), float(profit))
  i+=25
# Out:
# Ad$ Profit
# 0.0 0.0
# 25.0 75.0
# 50.0 90.0
# 75.0 105.0
# 100.0 100.0
# 125.0 95.0
# 150.0 90.0
# 175.0 85.0
# 200.0 80.0

# %%
# In-Class Assignment 6
import random

play = input("Do you want to play a game? (y/n): ")
while (play == 'y'):
  user_input = input("Please choose rock, paper or scissors: ")
  user_input = user_input.lower()

  while user_input != "rock" and user_input != "paper" and user_input != "scissors":
    user_input = input("Please choose rock, paper or scissors: ")
    user_input = user_input.lower()

  computer_choice = random.choice(["rock", "paper", "scissors"])
  print(f"Computer chose {computer_choice}")
  print(f"You chose {user_input}")

  if (user_input == "rock" and computer_choice == "scissors") or (user_input == "paper" and computer_choice == "rock") or (user_input == "scissors" and computer_choice == "paper"):
    print("You win!")
  elif user_input == computer_choice:
    print("It's a tie!")
  else:
    print("You lose!")

  play = input("Do you want to play again? (y/n): ")
# Out:
# Do you want to play a game? (y/n): y
# Please choose rock, paper or scissors: scissors
# Computer chose paper
# You chose scissors
# You win!
# Do you want to play again? (y/n): y
# Please choose rock, paper or scissors: roc];lm
# Please choose rock, paper or scissors: rock
# Computer chose rock
# You chose rock
# It's a tie!
# Do you want to play again? (y/n): n

# %%
# In Class Assignment #7
numbers = []

while True:
  num = float(input("Please enter a numerical input: "))
  if num == 0:
    break
  numbers.append(num)

numbers.sort(reverse=True)
print(numbers)
# Out:
# Please enter a numerical input: 5
# Please enter a numerical input: 8
# Please enter a numerical input: 2
# Please enter a numerical input: 1
# Please enter a numerical input: 7
# Please enter a numerical input: 0
# [8.0, 7.0, 5.0, 2.0, 1.0]

# %%
# In Class Assignment 8
weights = [10.0, 9.9, 10.1, 10.05]
print(sum(weights) / len(weights)) # average weights
print(max(weights)) # largest value
# Out:
# 10.0125
# 10.1

# %%
# In Class Assignment 9
product_id = {"P-01": 9.95,
              "P-02": 10.50}

user_input = input("Enter Product ID: ")
if user_input in product_id:
  print(f"{user_input} $" + str(product_id[user_input]))
else:
  print(f"{user_input} not found")
# Out:
# Please enter a product ID in the dictionary: fghj
# fghj not found

# %%
# In-Class Assignment #10
names = {}

while True:
  name = input("Please enter a name: ")
  if name == "":
    break
  if name in names:
    names[name] += 1
  else:
    names[name] = 1

print(names)
